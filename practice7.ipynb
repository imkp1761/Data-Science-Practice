# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent", "Food","Phone/Internet Bill", "Car","other Utilities"]

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels,autopct='%0.2f',explode=[0,0,0.1,0,0])
plt.show()
